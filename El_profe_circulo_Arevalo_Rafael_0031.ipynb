# %% [markdown]
# <a href="https://colab.research.google.com/github/ArevaloMurguia/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes-/blob/main/El_profe_circulo_Arevalo_Rafael_0031.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Arevalo Rafael NL = 3 Fecha:25/03/26 🥇
# ---
# ### Calcular Area y Perimetro de un Circulo
# ---
# ![AreaCirculo.jpg](data:image/jpeg;base64,...)
# ---
# ### Formula para Area
# A=π⋅r2
# ### Formula para calcular el perimetro
# P=2⋅π⋅
#
# ### Datos de entrada
# $r$?
# ### Diagrama de flujo de Lucichat
# ![Lucichat.PNG](data:image/png;base64,...)

# %%
# Calcular Area y Perimetro de un circulo
# Variables A, P, r
# Formulas A = pi * r^2 y P = 2 * pi * r
# Capturar el valor de r
import math
print("Calcular Area y Perimetro de un circulo")
r = float(input("Ingrese el valor de r: "))
A = math.pi * r ** 2
P = 2 * math.pi * r
print("El area del circulo es: ", A)
print("El perimetro del circulo es: ", P)
print("Arevalo Rafael NL = 3")
# Out:
# Calcular Area y Perimetro de un circulo
# Ingrese el valor de r: 5
# El area del circulo es:  78.53981633974483
# El perimetro del circulo es:  31.41592653589793
# Arevalo Rafael NL = 3

# %% [markdown]
# ### Relacion entre codigo y DF en Tldraw
# ![Archivo EPPL.PNG](data:image/png;base64,...)
